# %% [markdown]
# Zomato Dataset EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("zomato.csv", encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## IN Data Analysis the things we do
# 1. Missing values
# 2. Explore about the numerical Variables
# 3. Explore about categorical Variables
# 4. Finding Relationship between features

# %%
 df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
df1 = pd.read_csv("zomato.csv", encoding='latin-1').head(1000)
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_country=pd.read_excel('country-code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
final_df = pd.merge(df,df_country,on = 'Country Code', how='left')
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Country.value_counts() # from this we find how many entry in this country
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
country_names=final_df.Country.value_counts().index

# %%
country_val=final_df.Country.value_counts().values

# %%
plt.pie(country_val[:3],labels=country_names[:3], autopct="%0.2f%%") # here [:3] used to get top 3 countrys
# Out:
# ([<matplotlib.patches.Wedge at 0x1548c9c7c50>,
# ...
#  [Text(-1.082974277862112, 0.1927867046480056, 'India'),
#   Text(1.0772816964394372, -0.22240536530526556, 'United States'),
#   Text(1.0995865232164619, -0.030157552300104404, 'United Kingdom')],
#  [Text(-0.5907132424702428, 0.10515638435345759, '94.39%'),
#   Text(0.5876081980578747, -0.12131201743923574, '4.73%'),
#   Text(0.5997744672089791, -0.01644957398187513, '0.87%')])

# %% [markdown]
# observation : Zomato max records or transaction are from India, the US and then UK

# %%
ratings =final_df.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:'Rating Count '})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated           2148
# 1                1.8          Red        Poor              1
# 2                1.9          Red        Poor              2
# 3                2.0          Red        Poor              7
# 4                2.1          Red        Poor             15
# 5                2.2          Red        Poor             27
# 6                2.3          Red        Poor             47
# 7                2.4          Red        Poor             87
# 8                2.5       Orange     Average            110
# 9                2.6       Orange     Average            191
# 10               2.7       Orange     Average            250
# 11               2.8       Orange     Average            315
# 12               2.9       Orange     Average            381
# 13               3.0       Orange     Average            468
# ...

# %%
ratings.columns = ratings.columns.str.strip()  #Sometimes, column names have extra spaces. Fix them like this

# %% [markdown]
# ## observation
# 1. When rating is between 4.5 to 4.9 ---> Excellent
# 2. When rating is between 4.0 to 3.4 ---> Very good
# 3. When rating is between 3.5 to 3.9 ---> Good
# 4. When rating is between 2.4 to 3.4 ---> Average
# 5. When rating is between 1.8 to 2.4 ---> poor

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Aggregate rating", y="Rating Count", data=ratings, hue="Rating color",
           palette=['Blue','Red','Orange','Yellow','Green','Green'])
plt.show()

# %% [markdown]
# ## observation
# 1. not rated count is very high
# 2. the most number of rating between 2.5 to 3.4

# %%
 sns.countplot(x="Rating color",data = ratings, palette=['Blue','Red','Orange','Yellow','Green','Green'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_15504\3949998497.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Rating color",data = ratings, palette=['Blue','Red','Orange','Yellow','Green','Green'])
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# ## find the countrys name that has given 0 ratting

# %%
final_df.groupby(['Rating color','Country']).size().unstack()
# Out:
# Country       Australia  Brazil  Canada   India  Indonesia  New Zealand  \
# Rating color
# Dark Green          1.0    16.0     NaN   116.0        7.0         12.0
# Green               5.0    20.0     1.0   692.0       10.0         25.0
# Orange              4.0     8.0     2.0  3678.0        1.0          NaN
# Red                 1.0     NaN     NaN   180.0        NaN          1.0
# White               NaN     5.0     NaN  2139.0        NaN          NaN
# Yellow             13.0    11.0     1.0  1847.0        3.0          2.0
#
# Country       Phillipines  Qatar  Singapore  South Africa  Sri Lanka  Turkey  \
# Rating color
# Dark Green           12.0    4.0        NaN          12.0        2.0    10.0
# Green                 9.0    7.0        3.0          35.0       11.0    20.0
# Orange                NaN    2.0        9.0           1.0        2.0     1.0
# Red                   NaN    NaN        NaN           NaN        1.0     NaN
# ...

# %%
rating_null =final_df [final_df['Rating color']=='White'].groupby('Country').size().reset_index()
rating_null
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# ## Observation
# max 0 ratings are from india

# %%
## find out which currency is used by which country
final_df.groupby(['Currency','Country']).size().reset_index().drop(0,axis=1)
# Out:
#                   Currency         Country
# 0         Botswana Pula(P)     Phillipines
# 1       Brazilian Real(R$)          Brazil
# 2                Dollar($)       Australia
# 3                Dollar($)          Canada
# 4                Dollar($)       Singapore
# 5                Dollar($)   United States
# 6       Emirati Diram(AED)             UAE
# 7       Indian Rupees(Rs.)           India
# 8   Indonesian Rupiah(IDR)       Indonesia
# 9            NewZealand($)     New Zealand
# 10              Pounds(£)  United Kingdom
# 11         Qatari Rial(QR)           Qatar
# 12                 Rand(R)    South Africa
# 13   Sri Lankan Rupee(LKR)       Sri Lanka
# 14        Turkish Lira(TL)          Turkey

# %%
## Which country do have online delivery
final_df[final_df['Has Online delivery']=='Yes'].groupby(['Country']).size()
# Out:
# Country
# India    2423
# UAE        28
# dtype: int64

# %% [markdown]
# from this we find that India has done most online order , then UAE

# %%
final_df.groupby(['Has Online delivery','Country']).size()
# Out:
# Has Online delivery  Country
# No                   Australia           24
#                      Brazil              60
#                      Canada               4
#                      India             6229
#                      Indonesia           21
#                      New Zealand         40
#                      Phillipines         22
#                      Qatar               20
#                      Singapore           20
#                      South Africa        60
#                      Sri Lanka           20
#                      Turkey              34
#                      UAE                 32
#                      United Kingdom      80
#                      United States      434
# Yes                  India             2423
#                      UAE                 28
# dtype: int64

# %%
city_lables=final_df.City.value_counts().index
city_values=final_df.City.value_counts().values

# %%
## create a pie chart for cities distribution
plt.pie(city_values[:5],labels=city_lables[:5], autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1548b6f6210>,
# ...
#  [Text(-0.6145353730323401, 0.9123301350344637, 'New Delhi'),
#   Text(0.06236774886414425, -1.0982305149200777, 'Gurgaon'),
#   Text(0.878904221413572, -0.6614585169014024, 'Noida'),
#   Text(1.0922218482114119, -0.1305811406354216, 'Faridabad'),
#   Text(1.099946277419523, -0.010871374841004297, 'Ghaziabad')],
#  [Text(-0.33520111256309454, 0.4976346191097074, '68.87%'),
#   Text(0.03401877210771504, -0.5990348263200423, '14.07%'),
#   Text(0.479402302589221, -0.36079555467349217, '13.59%'),
#   Text(0.5957573717516791, -0.07122607671022996, '3.16%'),
#   Text(0.5999706967742853, -0.00592984082236598, '0.31%')])

# %%
new = final_df.Cuisines.value_counts().index
new
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'Chinese', 'Fast Food',
#        'North Indian, Mughlai', 'Cafe', 'Bakery',
#        'North Indian, Mughlai, Chinese', 'Bakery, Desserts', 'Street Food',
#        ...
#        'Goan, Seafood, Chinese, North Indian', 'Italian, Continental, Goan',
#        'Continental, American, Seafood',
#        'American, Fast Food, Steak, Beverages', 'Patisserie, Coffee and Tea',
#        'Kebab, Izgara', 'World Cuisine', 'World Cuisine, Mexican, Italian',
#        'Kebab, Turkish Pizza, Dí_ner', 'Turkish Pizza'],
#       dtype='object', name='Cuisines', length=1825)

# %%
new1 = final_df.Cuisines.value_counts().values
new1
# Out:
# array([936, 511, 354, ...,   1,   1,   1], shape=(1825,))

# %%
## create a pie chart for cities distribution
plt.pie(new1[:5],labels=new[:5], autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x154898d9590>,
# ...
#  [Text(0.4175822660282447, 1.0176566469584505, 'North Indian'),
#   Text(-1.0901695016598902, 0.14673260595595905, 'North Indian, Chinese'),
#   Text(-0.6326707688864324, -0.8998487085041855, 'Chinese'),
#   Text(0.30487652953108235, -1.0569060042128076, 'Fast Food'),
#   Text(1.003691693758835, -0.4501144119882426, 'North Indian, Mughlai')],
#  [Text(0.22777214510631527, 0.5550854437955184, '37.61%'),
#   Text(-0.5946379099963037, 0.08003596688506857, '20.53%'),
#   Text(-0.3450931466653267, -0.49082656827501026, '14.22%'),
#   Text(0.1662962888351358, -0.5764941841160768, '14.22%'),
#   Text(0.5474681965957281, -0.24551695199358683, '13.42%')])
